# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv("/content/drive/MyDrive/canada_percapita.csv")
df
# Out:
#     year        income
# 0   1970   3399.299037
# 1   1971   3768.297935
# 2   1972   4251.175484
# 3   1973   4804.463248
# 4   1974   5576.514583
# 5   1975   5998.144346
# 6   1976   7062.131392
# 7   1977   7100.126170
# 8   1978   7247.967035
# 9   1979   7602.912681
# 10  1980   8355.968120
# 11  1981   9434.390652
# 12  1982   9619.438377
# 13  1983  10416.536590
# 14  1984  10790.328720
# 15  1985  11018.955850
# 16  1986  11482.891530
# 17  1987  12974.806620
# 18  1988  15080.283450
# 19  1989  16426.725480
# 20  1990  16838.673200
# 21  1991  17266.097690
# 22  1992  16412.083090
# 23  1993  15875.586730
# 24  1994  15755.820270
# 25  1995  16369.317250
# 26  1996  16699.826680
# 27  1997  17310.757750
# 28  1998  16622.671870
# 29  1999  17581.024140
# 30  2000  18987.382410
# 31  2001  18601.397240
# 32  2002  19232.175560
# 33  2003  22739.426280
# 34  2004  25719.147150
# 35  2005  29198.055690
# 36  2006  32738.262900
# 37  2007  36144.481220
# 38  2008  37446.486090
# ...

# %%
df.head(2)
# Out:
#    year       income
# 0  1970  3399.299037
# 1  1971  3768.297935

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per capita income (us$)')
plt.scatter(df.year,df.income,color='red',marker='+')

# %%
x=df.drop('income',axis='columns')
x
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
y=df.drop('year',axis='columns')
y
# Out:
#           income
# 0    3399.299037
# 1    3768.297935
# 2    4251.175484
# 3    4804.463248
# 4    5576.514583
# 5    5998.144346
# 6    7062.131392
# 7    7100.126170
# 8    7247.967035
# 9    7602.912681
# 10   8355.968120
# 11   9434.390652
# 12   9619.438377
# 13  10416.536590
# 14  10790.328720
# 15  11018.955850
# 16  11482.891530
# 17  12974.806620
# 18  15080.283450
# 19  16426.725480
# 20  16838.673200
# 21  17266.097690
# 22  16412.083090
# 23  15875.586730
# 24  15755.820270
# 25  16369.317250
# 26  16699.826680
# 27  17310.757750
# 28  16622.671870
# 29  17581.024140
# 30  18987.382410
# 31  18601.397240
# 32  19232.175560
# 33  22739.426280
# 34  25719.147150
# 35  29198.055690
# 36  32738.262900
# 37  36144.481220
# 38  37446.486090
# 39  32755.176820
# 40  38420.522890
# 41  42334.711210
# 42  42665.255970
# 43  42676.468370
# 44  41039.893600
# 45  35175.188980
# 46  34229.193630

# %%
reg=LinearRegression()

# %%
reg.fit(df[['year']],df.income)
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([41288.69409442])

# %%
plt.figure(figsize=(10,7))
plt.xlabel('year',fontsize=15)
plt.ylabel('per capita income (US$)',fontsize=15)
plt.scatter (df.year , df.income, color = 'red',marker='*' )
plt.plot(df.year , reg.predict(df[['year']]) , color='blue')

# %%
r2_score=reg.score(x,y)
r2_score
# Out:
# 0.890916917957032

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# -1632210.7578554575

# %%
a=2078
for i in range(2017,):
  print(i)
  print("\n")
# Out:
# 2017
#
#
# 2018
#
#
# 2019
#
#
# 2020
#
#
# 2021
#
#
# 2022
#
#
# 2023
#
#
# 2024
#
#
# 2025
#
#
# 2026
#
#
# 2027
#
#
# 2028
#
#
# 2029
#
#
# 2030
#
#
# 2031
#
#
# 2032
#
#
# 2033
#
#
# 2034
#
#
# 2035
#
#
# 2036
#
#
# 2037
#
#
# 2038
#
#
# 2039
#
#
# 2040
#
#
# 2041
#
#
# 2042
#
#
# 2043
#
#
# 2044
#
#
# 2045
#
#
# 2046
#
#
# 2047
#
#
# 2048
#
#
# 2049
#
#
# 2050
#
#
# 2051
#
#
# 2052
#
#
# 2053
#
#
# 2054
#
#
# 2055
#
#
# 2056
#
#
# 2057
#
#
# 2058
#
#
# 2059
#
#
# 2060
#
#
# 2061
#
#
# 2062
#
#
# 2063
#
#
# 2064
#
#
# 2065
#
#
# 2066
#
#
# 2067
#
#
# 2068
#
#
# 2069
#
#
# 2070
#
#
# 2071
#
#
# 2072
#
#
# 2073
#
#
# 2074
#
#
# 2075
#
#
# 2076
#
#
# 2077

# %%
ds=pd.read_csv("/content/drive/MyDrive/years_canada.csv")
#ds.drop('unnamed',axis=0)
ds
# Out:
#     year
# 0   2017
# 1   2018
# 2   2019
# 3   2020
# 4   2021
# 5   2022
# 6   2023
# 7   2024
# 8   2025
# 9   2026
# 10  2027
# 11  2028
# 12  2029
# 13  2030
# 14  2031

# %%
p=reg.predict(ds)

# %%
ds['income']=p
ds
# Out:
#     year        income
# 0   2017  38803.298869
# 1   2018  39631.763944
# 2   2019  40460.229019
# 3   2020  41288.694094
# 4   2021  42117.159170
# 5   2022  42945.624245
# 6   2023  43774.089320
# 7   2024  44602.554395
# 8   2025  45431.019471
# 9   2026  46259.484546
# 10  2027  47087.949621
# 11  2028  47916.414696
# 12  2029  48744.879771
# 13  2030  49573.344847
# 14  2031  50401.809922

# %%
ds.to_csv("/content/drive/MyDrive/years_canada.csv")
